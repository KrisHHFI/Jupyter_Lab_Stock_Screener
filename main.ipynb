# %%
from utils.const.filters import MIN_MARKET_CAP_FILTER, SCREEN_SIZE_FILTER, TOP_N_FILTER
from utils.yfinance.call_tracker.get_yfinance_call_count import get_yfinance_call_count
from utils.yfinance.call_tracker.get_yfinance_call_log import get_yfinance_call_log
from utils.yfinance.call_tracker.reset_yfinance_call_count import reset_yfinance_call_count
from utils.yfinance.call_tracker.set_yfinance_call_delay import set_yfinance_call_delay
from utils.yfinance.get_top_pe_us_fast_food_stock import get_top_pe_us_fast_food_stock
from utils.printing.print_stock_info import print_stock_info
from utils.printing.print_data_collected import print_data_collected

delay_seconds = 1.5
top_n = TOP_N_FILTER

try:
    reset_yfinance_call_count()
    set_yfinance_call_delay(delay_seconds)

    stock_info = get_top_pe_us_fast_food_stock(
        min_market_cap=MIN_MARKET_CAP_FILTER,
        top_n=top_n,
        screen_size=SCREEN_SIZE_FILTER,
        verify_with_info=False,
    )

    print_stock_info(stock_info)
    print_data_collected(
        yfinance_call_count=get_yfinance_call_count(),
        yfinance_call_delay=delay_seconds,
        yfinance_call_log=get_yfinance_call_log(),
    )
except Exception as e:
    print(f"Error: {e}")
# Out:
# ───────────────────────────────────────────────── STOCK SCREENER ──────────────────────────────────────────────────
# ───────────────────────────────────────────────────── FILTERS ─────────────────────────────────────────────────────
# <style type="text/css">
# #T_7d487 table {
#   border-collapse: collapse;
#   width: 100%;
# }
# #T_7d487 th {
#   border: 1px solid #888;
#   background-color: #ffffff;
#   color: #000000;
#   text-align: left;
#   padding: 6px;
# }
# #T_7d487 td {
#   border: 1px solid #888;
#   padding: 6px;
# }
# #T_7d487_row0_col0, #T_7d487_row0_col1, #T_7d487_row1_col0, #T_7d487_row1_col1, #T_7d487_row2_col0, #T_7d487_row2_col1 {
#   text-align: left;
#   padding: 6px;
# }
# </style>
# <table id="T_7d487">
#   <thead>
#     <tr>
#       <th id="T_7d487_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_7d487_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7d487_row0_col0" class="data row0 col0" >Filter Region</td>
#       <td id="T_7d487_row0_col1" class="data row0 col1" >US</td>
#     </tr>
#     <tr>
#       <td id="T_7d487_row1_col0" class="data row1 col0" >Filter Industry</td>
#       <td id="T_7d487_row1_col1" class="data row1 col1" >Restaurants / Fast Food</td>
#     </tr>
#     <tr>
#       <td id="T_7d487_row2_col0" class="data row2 col0" >Filter Min Market Cap</td>
#       <td id="T_7d487_row2_col1" class="data row2 col1" >2.0B</td>
#     </tr>
#   </tbody>
# </table>
# ───────────────────────────────────────────────────── SORTING ─────────────────────────────────────────────────────
# <style type="text/css">
# #T_46b80 table {
#   border-collapse: collapse;
#   width: 100%;
# }
# #T_46b80 th {
#   border: 1px solid #888;
#   background-color: #ffffff;
#   color: #000000;
#   text-align: left;
#   padding: 6px;
# }
# #T_46b80 td {
#   border: 1px solid #888;
#   padding: 6px;
# }
# #T_46b80_row0_col0, #T_46b80_row0_col1, #T_46b80_row1_col0, #T_46b80_row1_col1 {
#   text-align: left;
#   padding: 6px;
# }
# </style>
# <table id="T_46b80">
#   <thead>
#     <tr>
#       <th id="T_46b80_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_46b80_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_46b80_row0_col0" class="data row0 col0" >Sorted By</td>
#       <td id="T_46b80_row0_col1" class="data row0 col1" >P/E Ratio (last twelve months)</td>
#     </tr>
#     <tr>
#       <td id="T_46b80_row1_col0" class="data row1 col0" >Direction</td>
#       <td id="T_46b80_row1_col1" class="data row1 col1" >Descending</td>
#     </tr>
#   </tbody>
# </table>
# ───────────────────────────────────────────────────── RESULTS ─────────────────────────────────────────────────────
# <style type="text/css">
# #T_398a9 table {
#   border-collapse: collapse;
#   width: 100%;
# }
# #T_398a9 th {
#   border: 1px solid #888;
#   background-color: #ffffff;
#   color: #000000;
#   text-align: left;
#   padding: 6px;
# }
# #T_398a9 td {
#   border: 1px solid #888;
#   padding: 6px;
# }
# #T_398a9_row0_col0, #T_398a9_row0_col1, #T_398a9_row0_col2, #T_398a9_row0_col3, #T_398a9_row0_col4, #T_398a9_row0_col5, #T_398a9_row1_col0, #T_398a9_row1_col1, #T_398a9_row1_col2, #T_398a9_row1_col3, #T_398a9_row1_col4, #T_398a9_row1_col5, #T_398a9_row2_col0, #T_398a9_row2_col1, #T_398a9_row2_col2, #T_398a9_row2_col3, #T_398a9_row2_col4, #T_398a9_row2_col5, #T_398a9_row3_col0, #T_398a9_row3_col1, #T_398a9_row3_col2, #T_398a9_row3_col3, #T_398a9_row3_col4, #T_398a9_row3_col5, #T_398a9_row4_col0, #T_398a9_row4_col1, #T_398a9_row4_col2, #T_398a9_row4_col3, #T_398a9_row4_col4, #T_398a9_row4_col5, #T_398a9_row5_col0, #T_398a9_row5_col1, #T_398a9_row5_col2, #T_398a9_row5_col3, #T_398a9_row5_col4, #T_398a9_row5_col5, #T_398a9_row6_col0, #T_398a9_row6_col1, #T_398a9_row6_col2, #T_398a9_row6_col3, #T_398a9_row6_col4, #T_398a9_row6_col5, #T_398a9_row7_col0, #T_398a9_row7_col1, #T_398a9_row7_col2, #T_398a9_row7_col3, #T_398a9_row7_col4, #T_398a9_row7_col5, #T_398a9_row8_col0, #T_398a9_row8_col1, #T_398a9_row8_col2, #T_398a9_row8_col3, #T_398a9_row8_col4, #T_398a9_row8_col5, #T_398a9_row9_col0, #T_398a9_row9_col1, #T_398a9_row9_col2, #T_398a9_row9_col3, #T_398a9_row9_col4, #T_398a9_row9_col5 {
#   text-align: left;
#   padding: 6px;
# }
# </style>
# <table id="T_398a9">
#   <thead>
#     <tr>
#       <th id="T_398a9_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_398a9_level0_col1" class="col_heading level0 col1" >Symbol</th>
#       <th id="T_398a9_level0_col2" class="col_heading level0 col2" >Company</th>
#       <th id="T_398a9_level0_col3" class="col_heading level0 col3" >P/E Ratio</th>
#       <th id="T_398a9_level0_col4" class="col_heading level0 col4" >Market Cap</th>
#       <th id="T_398a9_level0_col5" class="col_heading level0 col5" >Current Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_398a9_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_398a9_row0_col1" class="data row0 col1" >SHAK</td>
#       <td id="T_398a9_row0_col2" class="data row0 col2" >Shake Shack, Inc.</td>
#       <td id="T_398a9_row0_col3" class="data row0 col3" >91.72</td>
#       <td id="T_398a9_row0_col4" class="data row0 col4" >3.99B</td>
#       <td id="T_398a9_row0_col5" class="data row0 col5" >93.56</td>
#     </tr>
#     <tr>
#       <td id="T_398a9_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_398a9_row1_col1" class="data row1 col1" >BROS</td>
#       <td id="T_398a9_row1_col2" class="data row1 col2" >Dutch Bros Inc.</td>
#       <td id="T_398a9_row1_col3" class="data row1 col3" >76.26</td>
#       <td id="T_398a9_row1_col4" class="data row1 col4" >8.03B</td>
#       <td id="T_398a9_row1_col5" class="data row1 col5" >48.81</td>
#     </tr>
#     <tr>
#       <td id="T_398a9_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_398a9_row2_col1" class="data row2 col1" >CAVA</td>
#       <td id="T_398a9_row2_col2" class="data row2 col2" >CAVA Group, Inc.</td>
#       <td id="T_398a9_row2_col3" class="data row2 col3" >60.43</td>
#       <td id="T_398a9_row2_col4" class="data row2 col4" >8.13B</td>
#       <td id="T_398a9_row2_col5" class="data row2 col5" >70.11</td>
#     </tr>
#     <tr>
#       <td id="T_398a9_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_398a9_row3_col1" class="data row3 col1" >SBUX</td>
#       <td id="T_398a9_row3_col2" class="data row3 col2" >Starbucks Corporation</td>
#       <td id="T_398a9_row3_col3" class="data row3 col3" >81.23</td>
#       <td id="T_398a9_row3_col4" class="data row3 col4" >111.07B</td>
#       <td id="T_398a9_row3_col5" class="data row3 col5" >97.49</td>
#     </tr>
#     <tr>
#       <td id="T_398a9_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_398a9_row4_col1" class="data row4 col1" >WING</td>
#       <td id="T_398a9_row4_col2" class="data row4 col2" >Wingstop Inc.</td>
#       <td id="T_398a9_row4_col3" class="data row4 col3" >42.35</td>
#       <td id="T_398a9_row4_col4" class="data row4 col4" >7.28B</td>
#       <td id="T_398a9_row4_col5" class="data row4 col5" >260.89</td>
#     </tr>
#     <tr>
#       <td id="T_398a9_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_398a9_row5_col1" class="data row5 col1" >CMG</td>
#       <td id="T_398a9_row5_col2" class="data row5 col2" >Chipotle Mexican Grill, Inc.</td>
#       <td id="T_398a9_row5_col3" class="data row5 col3" >32.92</td>
#       <td id="T_398a9_row5_col4" class="data row5 col4" >49.63B</td>
#       <td id="T_398a9_row5_col5" class="data row5 col5" >37.54</td>
#     </tr>
#     <tr>
#       <td id="T_398a9_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_398a9_row6_col1" class="data row6 col1" >YUM</td>
#       <td id="T_398a9_row6_col2" class="data row6 col2" >Yum! Brands, Inc.</td>
#       <td id="T_398a9_row6_col3" class="data row6 col3" >29.42</td>
#       <td id="T_398a9_row6_col4" class="data row6 col4" >45.34B</td>
#       <td id="T_398a9_row6_col5" class="data row6 col5" >163.33</td>
#     </tr>
#     <tr>
#       <td id="T_398a9_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_398a9_row7_col1" class="data row7 col1" >TXRH</td>
#       <td id="T_398a9_row7_col2" class="data row7 col2" >Texas Roadhouse, Inc.</td>
#       <td id="T_398a9_row7_col3" class="data row7 col3" >27.34</td>
#       <td id="T_398a9_row7_col4" class="data row7 col4" >11.88B</td>
#       <td id="T_398a9_row7_col5" class="data row7 col5" >178.82</td>
#     </tr>
#     <tr>
#       <td id="T_398a9_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_398a9_row8_col1" class="data row8 col1" >MCD</td>
#       <td id="T_398a9_row8_col2" class="data row8 col2" >McDonald's Corporation</td>
#       <td id="T_398a9_row8_col3" class="data row8 col3" >27.55</td>
#       <td id="T_398a9_row8_col4" class="data row8 col4" >234.93B</td>
#       <td id="T_398a9_row8_col5" class="data row8 col5" >329.23</td>
#     </tr>
#     <tr>
#       <td id="T_398a9_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_398a9_row9_col1" class="data row9 col1" >CMPGY</td>
#       <td id="T_398a9_row9_col2" class="data row9 col2" >Compass Group Plc</td>
#       <td id="T_398a9_row9_col3" class="data row9 col3" >27.25</td>
#       <td id="T_398a9_row9_col4" class="data row9 col4" >50.97B</td>
#       <td id="T_398a9_row9_col5" class="data row9 col5" >29.98</td>
#     </tr>
#   </tbody>
# </table>
# ────────────────────────────────────────────────── CALL METADATA ──────────────────────────────────────────────────
# <style type="text/css">
# #T_95c88 table {
#   border-collapse: collapse;
#   width: 100%;
# }
# #T_95c88 th {
#   border: 1px solid #888;
#   background-color: #ffffff;
#   color: #000000;
#   text-align: left;
#   padding: 6px;
# }
# #T_95c88 td {
#   border: 1px solid #888;
#   padding: 6px;
# }
# #T_95c88_row0_col0, #T_95c88_row0_col1, #T_95c88_row1_col0, #T_95c88_row1_col1, #T_95c88_row2_col0, #T_95c88_row2_col1 {
#   text-align: left;
#   padding: 6px;
# }
# </style>
# <table id="T_95c88">
#   <thead>
#     <tr>
#       <th id="T_95c88_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_95c88_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_95c88_row0_col0" class="data row0 col0" >yfinance calls made</td>
#       <td id="T_95c88_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_95c88_row1_col0" class="data row1 col0" >Call delay (seconds)</td>
#       <td id="T_95c88_row1_col1" class="data row1 col1" >1.50</td>
#     </tr>
#     <tr>
#       <td id="T_95c88_row2_col0" class="data row2 col0" >Data collected on</td>
#       <td id="T_95c88_row2_col1" class="data row2 col1" >2026-02-21 17:46:59</td>
#     </tr>
#   </tbody>
# </table>
# CALL LOG
# <style type="text/css">
# #T_4d69d table {
#   border-collapse: collapse;
#   width: 100%;
# }
# #T_4d69d th {
#   border: 1px solid #888;
#   background-color: #ffffff;
#   color: #000000;
#   text-align: left;
#   padding: 6px;
# }
# #T_4d69d td {
#   border: 1px solid #888;
#   padding: 6px;
# }
# #T_4d69d_row0_col0 {
#   text-align: left;
#   padding: 6px;
# }
# </style>
# <table id="T_4d69d">
#   <thead>
#     <tr>
#       <th id="T_4d69d_level0_col0" class="col_heading level0 col0" >Entry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4d69d_row0_col0" class="data row0 col0" >Call #1 at 2026-02-21 17:46:57 -> yf.screen(query=US + Restaurants + min market cap)</td>
#     </tr>
#   </tbody>
# </table>
